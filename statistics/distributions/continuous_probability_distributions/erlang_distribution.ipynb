# %% [markdown]
# ## **Theoretical Foundation:**
# The Erlang distribution is a specialized, rigid sub-case of the Gamma distribution
# where the shape parameter $k$ is constrained to be a strictly positive integer.

# %% [markdown]
# $$f(x) = \frac{\lambda^k x^{k-1} e^{-\lambda x}}{(k-1)!}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import erlang

k_erlang = 5 # Must be an integer
dist_erlang = erlang(a=k_erlang, scale=1.0)

x_vals = np.linspace(0, 15, 1000)
fig, ( ax1, ax2 ) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(x_vals, dist_erlang.pdf(x_vals), color='navy', lw=3)
ax1.set_title(f'Erlang PDF (k={k_erlang})')
ax2.plot(x_vals, dist_erlang.cdf(x_vals), color='navy', lw=3)
ax2.set_title(f'Erlang CDF (k={k_erlang})')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from scipy.stats import erlang
#       4
#       5 k_erlang = 5 # Must be an integer
#       6 dist_erlang = erlang(a=k_erlang, scale=1.0)
#
# File c:\Users\dimal\Projects\mathematics\.venv\Lib\site-packages\scipy\stats\__init__.py:628
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    623
#     624 """  # noqa: E501
#     626 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     627                                DegenerateDataWarning, FitError)
# --> 628 from ._stats_py import *
#     629 from ._variation import variation
#     630 from .distributions import *
#
# File c:\Users\dimal\Projects\mathematics\.venv\Lib\site-packages\scipy\stats\_stats_py.py:40
#      36 import numpy as np
#      37 from numpy import array, asarray, ma
#      38
#      39 from scipy import sparse
# ---> 40 from scipy.spatial import distance_matrix
#      41
#      42 from scipy.optimize import milp, LinearConstraint
#      43 from scipy._lib._util import _get_nan, _rename_parameter, _contains_nan, np_vecdot
#
# File c:\Users\dimal\Projects\mathematics\.venv\Lib\site-packages\scipy\spatial\__init__.py:113
#     111 from ._kdtree import *
#     112 from ._ckdtree import *  # type: ignore[import-not-found]
# --> 113 from ._qhull import *
#     114 from ._spherical_voronoi import SphericalVoronoi
#     115 from ._plotutils import *
#
# File scipy/spatial/_qhull.pyx:1, in init scipy.spatial._qhull()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\dimal\Projects\mathematics\.venv\Lib\site-packages\scipy\linalg\__init__.py:201
#       1 """
#       2 ====================================
#       3 Linear algebra (:mod:`scipy.linalg`)
#    (...)    198
#     199 """  # noqa: E501
# --> 201 from ._misc import *
#     202 from ._cythonized_array_utils import *
#     203 from ._basic import *
#
# File c:\Users\dimal\Projects\mathematics\.venv\Lib\site-packages\scipy\linalg\_misc.py:3
#       1 import numpy as np
#       2 from numpy.linalg import LinAlgError
# ----> 3 from .blas import get_blas_funcs
#       4 from .lapack import get_lapack_funcs
#       6 __all__ = ['LinAlgError', 'LinAlgWarning', 'norm']
#
# File c:\Users\dimal\Projects\mathematics\.venv\Lib\site-packages\scipy\linalg\blas.py:224
#     221 import numpy as np
#     222 import functools
# --> 224 from scipy.linalg import _fblas
#     225 try:
#     226     from scipy.linalg import _cblas
#
# KeyboardInterrupt:

# %% [markdown]
# ## **Practical Application:**
# Invented by A.K. Erlang to examine the number of telephone calls concurrently
# handled by human operators, it remains fundamental in teletraffic engineering
# and server load balancing to calculate waiting times in multi-node networks.

# %% [markdown]
# ## **Interesting Fact:**
# Because $k$ is strictly an integer, the normalization constant uses the simple
# factorial $(k-1)!$ rather than the complex analytical Gamma function $\Gamma(k)$
# required by the broader Gamma distribution, accelerating computational rendering
# in massive simulations.
